# %%
from poly import *

# %%
p = petal_FT(n_border=40,n_petals=6,profile_type='arch_cos',profile_path='Matlab_files/NW2.mat')

# %%
rEj = rot(p.Ej)
Gammap = p.Gamma - rEj*100
Gammad = p.Gamma + 2*p.Ej

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')
# Out:
# /var/folders/by/0hym5dqx39s8h31mkk5db8fh0000gn/T/ipykernel_33803/1518606999.py:4: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg')

# %%
fig = plt.figure()
ax = fig.gca()
for i in range(p.npoints):
    plt.plot([p.Gamma[i,0],Gammap[i,0]],[p.Gamma[i,1],Gammap[i,1]],c='gray',alpha=0.1)
    plt.plot([p.Gamma[i,0],Gammad[i,0]],[p.Gamma[i,1],Gammad[i,1]],c='red',alpha=1)
#plt.scatter(p.Gamma[:,0],p.Gamma[:,1],s=10)
ax.axis('equal')
# Out:
# (-2.2752589674186465,
#  2.2752589674186248,
#  -2.5305685917691654,
#  2.530568591769188)

# %%
fig.savefig('Boivin-demo.png')

# %% [markdown]
# ### Figure comparing pixelized mask and polygonal mask

# %%
p = petal_FT(n_border=40,profile_type='sister',profile_path='Matlab_files/NW2.mat')

# %%
plt.scatter(p.Gamma[:,0],p.Gamma[:,1],s=1)

# %%
m = p.pixelized_mask(embed_factor=1)

# %%
plt.imshow(np.fft.fftshift(m),extent=p.pixelized_bbox())
